# %% [markdown]
# <a href="https://colab.research.google.com/github/kany2000/-/blob/main/%E8%8A%82%E7%82%B9%E6%8A%93.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/wzdnzd/aggregator.git
# Out:
# Cloning into 'aggregator'...
# remote: Enumerating objects: 2729, done.
# remote: Total 2729 (delta 0), reused 0 (delta 0), pack-reused 2729 (from 1)
# Receiving objects: 100% (2729/2729), 598.56 MiB | 18.61 MiB/s, done.
# Resolving deltas: 100% (1668/1668), done.
# Updating files: 100% (483/483), done.

# %%
# %cd aggregator
# Out:
# /content/aggregator

# %%
# !pip install -r requirements.txt
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 28.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.1/88.1 kB 7.3 MB/s eta 0:00:00
# ...
#   Created wheel for fofa-hack: filename=fofa_hack-2.5.2-py3-none-any.whl size=31469 sha256=3a8f7d832b00a9ed64b82aa0311692027f2d905056ff4fa6d147eabf640ba713
#   Stored in directory: /root/.cache/pip/wheels/be/24/dd/2a217b13b9f502c53f1c1212b2025abb144311371b77f848b3
# Successfully built fofa-hack
# ...

# %%
# !python -u subscribe/collect.py -s
# Out:
# 2025-04-04 04:26:56 collect.py [line:205] ERROR: cannot extract username and gist id due to invalid github gist link
# 2025-04-04 04:26:56 collect.py [line:68] INFO: start checking whether existing subscriptions have expired
# 2025-04-04 04:26:56 collect.py [line:110] INFO: load exists subscription finished, count: 0
# 2025-04-04 04:26:56 crawl.py [line:1431] INFO: [TelegramCrawl] starting crawl from telegram, channel: jichang_list, pages: 206
# 2025-04-04 04:26:56 crawl.py [line:1391] INFO: [AirPortCrawl] start collect airport, url: https://t.me/s/jichang_list?before=4115
# 2025-04-04 04:26:56 crawl.py [line:1391] INFO: [AirPortCrawl] start collect airport, url: https://t.me/s/jichang_list?before=4095
# 2025-04-04 04:26:56 crawl.py [line:1391] INFO: [AirPortCrawl] start collect airport, url: https://t.me/s/jichang_list?before=4075
# 2025-04-04 04:26:56 crawl.py [line:1391] INFO: [AirPortCrawl] start collect airport, url: https://t.me/s/jichang_list?before=4055
# ...

# %%
# !cat /content/aggregator/data/v2ray.txt
# Out:
# ...

# %%
from google.colab import files
files.download('/content/aggregator/data/v2ray.txt')
